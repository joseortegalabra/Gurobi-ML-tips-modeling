# %% [markdown]
# # Optimization automatization full - auto relaxing constrints
# In this notebook you can see the optimization engine, calling a script to get the optimization (optimization engine). If the engine return an infeasible solution there is a for that relaxing the constaints until get a feasible solution (in teory)

# %% [markdown]
# ## Root folder and read env variables

# %%
import os
# fix root path to save outputs
actual_path = os.path.abspath(os.getcwd())
list_root_path = actual_path.split('\\')[:-1]
root_path = '\\'.join(list_root_path)
os.chdir(root_path)
print('root path: ', root_path)
# Out:
# root path:  D:\github-mi-repo\Gurobi-ML-tips-modeling

# %%
import os
from dotenv import load_dotenv, find_dotenv # package used in jupyter notebook to read the variables in file .env

""" get env variable from .env """
load_dotenv(find_dotenv())

""" Read env variables and save it as python variable """
PROJECT_GCP = os.environ.get("PROJECT_GCP", "")

# %% [markdown]
# ## Load licence gurobi

# %%
##########  LOAD LICENCE GUROBI ##########
import gurobipy as gp

# set env variable with the path of the licence
name_file_licence_gurobi = "gurobi.lic"
path_licence_gurobi = root_path + '\\' + name_file_licence_gurobi
os.environ ["GRB_LICENSE_FILE"] = path_licence_gurobi
print(os.environ["GRB_LICENSE_FILE"])
# Out:
# D:\github-mi-repo\Gurobi-ML-tips-modeling\gurobi.lic

# %%
######### LAOD CONTENT LICENCE GUROBI #########
with open(path_licence_gurobi, 'r') as f:
    content_licence = f.read()
WLSACCESSID = content_licence.split('\n')[3].split('=')[1] # load WLSACCESSID (string)
WLSSECRET = content_licence.split('\n')[4].split('=')[1] # load WLSSECRET (string)
LICENSEID = int(content_licence.split('\n')[5].split("=")[1]) # load LICENSEID (integer)

params = {
"WLSACCESSID": WLSACCESSID,
"WLSSECRET": WLSSECRET,
"LICENSEID": LICENSEID
}

# %% [markdown]
# ## RUN

# %%
import pickle
import pandas as pd
import numpy as np

#gurobi
import gurobipy_pandas as gppd
from gurobi_ml import add_predictor_constr
import gurobipy as gp

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## IMPORTANTE LOS ARCHIVOS DE CONFIGURACIÓN SE LEEN AFUERA DEL SCRIPT DE OPTIMIZACIÓN PORQUE AFUERA ESTÁ EL CÓDIGO PARA RELAX LAS RESTRICCIONES CAMBIANDO LOS PARÁMETROS Y LUEGO EL SCRIPT RECIBE LOS VALORES EXACTOS CON LOS QUE TIENE QUE RESOLVER EL PROBLEMA DE OPTIMIZACIÓN
#
# - **PARA SIMPLIFICAR TODO, LEO TODOS LOS ARCHIVOS DE CONFIGURACIÓN AFUERA, AUNQUE ALGUNOS NO SE RELAJEN NUNCA, COMO POR EJEMPLO LOS ARCHIVOS QUE CONFIGURAN LA RED**

# %% [markdown]
# ### 1. Load configuration file optimizer and configuration instance to solve
# The are principally two kind of files to config optimizer
# - **configuration file to create optimizer**: there a files used to create the optimization network such as, list of sets, list of variables, upper bound and lower bound, etc. Pricipally in this files should be parameters that doesn't change too much across the time. For example, the list of variable, is a parameter that if change, the structure of the network change and the machine learning models needs to change too
#
# - **configuration file with instance to solve**: there files that change its values every time that the optimizer solve the problem. It represents the files with the actual values of the features, and so, this values change every time that the optimizer is executed

# %% [markdown]
# #### 1.1. IndexTime file

# %%
#################### define set ####################

## paths and files names
path_folder_config_optimization = f'config/optimization_engine/config_optimization/'
file_indextime = 'IndexTime.xlsx'
path_indextime = path_folder_config_optimization + file_indextime

# read file
indextime = pd.read_excel(path_indextime)

# set index
index_set_time = pd.Index(indextime['IndexTime'].values)
index_set_time
# Out:
# Index(['t0', 't1', 't2', 't3', 't4', 't5', 't6'], dtype='object')

# %% [markdown]
# #### 1.2 Decision variables

# %%
#################### define decision variables ####################

# paths and file names
path_folder_config_optimization = f'config/optimization_engine/config_optimization/'
file_allvariables = 'allVariables.xlsx'
path_allvariables = path_folder_config_optimization + file_allvariables

# read file
config_allvariables = pd.read_excel(path_allvariables)

# table
config_allvariables
# Out:
#     tag feature_name                                        description  \
# 0    X1           X1  Variable de entrada al proceso A. Variable Pri...
# 1    O1           O1  Variable de entrada al proceso A. No es una va...
# 2    O2           O2  Variable de entrada al proceso A. No es una va...
# 3    O3           O3  Variable de entrada al proceso A. No es una va...
# 4    Y1           Y1  Variable target del proceso A y Variable de en...
# 5    O4           O4  Variable de entrada al proceso tanque TANK1. N...
# 6    Z1           Z1  Variable de salida del tanque X y Variable de ...
# 7    X2           X2  Variable de entrada al proceso B. Aparece por ...
# 8    O5           O5  Variable de entrada al proceso B. No es una va...
# 9    O6           O6  Variable de entrada al proceso B. No es una va...
# 10   Y2           Y2  Variable target del proceso B y proceso C (y v...
# 11   Y3           Y3  Variable target del proceso B que finaliza el ...
# 12   X3           X3  Variable de entrada al proceso C. Aparece por ...
# 13   O7           O7  Variable de entrada al proceso C. No es una va...
# 14  TL1          TL1                                Tank level - tank 1
# 15  TL2          TL2                                Tank level - tank 2
# 16  TL3          TL3                                Tank level - tank 3
#
#    clasification_name clasification  lower    upper  rate_change
# 0             Primary             P    0.0   1000.0        100.0
# 1            Observed             O    NaN      NaN          NaN
# 2            Observed             O    NaN      NaN          NaN
# 3            Observed             O    NaN      NaN          NaN
# 4              Target             T    0.0    400.0        100.0
# 5            Observed             O    NaN      NaN          NaN
# 6           Secundary             S    0.0   1000.0        100.0
# 7             Primary             P    0.0   1000.0        100.0
# 8            Observed             O    NaN      NaN          NaN
# 9            Observed             O    NaN      NaN          NaN
# 10             Target             T    0.0    500.0        100.0
# 11             Target             T    0.0    450.0        100.0
# 12            Primary             P    0.0   1500.0        100.0
# 13           Observed             O    NaN      NaN          NaN
# 14         Tank level             L  100.0  20000.0         10.0
# 15         Tank level             L  100.0  20000.0         10.0
# 16         Tank level             L  100.0  20000.0         10.0

# %% [markdown]
# #### 1.3 Initial Values
# -  This configuration files corresponde to the description **"configuration file with instance to solve"**. This file has the initial values to start the optimizer
# -  **OBS: the decision variable that are targets of machine learning models its initial value it nos defined. For all the optimization process since t=0 to t=N all the values are predicted by ml model**

# %%
#################### define initial values ####################

# paths and file names
path_folder_config_optimization = f'config/optimization_engine/config_optimization/'
file_initvalues = 'InitialValues.xlsx'
path_initvalues = path_folder_config_optimization + file_initvalues

# read file
config_initvalues = pd.read_excel(path_initvalues)

# table
config_initvalues
# Out:
#     tag feature_name  init_values
# 0    X1           X1         50.0
# 1    O1           O1         50.0
# 2    O2           O2         50.0
# 3    O3           O3         50.0
# 4    Y1           Y1          NaN
# 5    O4           O4        200.0
# 6    Z1           Z1          NaN
# 7    X2           X2          5.0
# 8    O5           O5          5.0
# 9    O6           O6          5.0
# 10   Y2           Y2          NaN
# 11   Y3           Y3          NaN
# 12   X3           X3          5.0
# 13   O7           O7          4.0
# 14  TL1          TL1        500.0
# 15  TL2          TL2        500.0
# 16  TL3          TL3        500.0

# %% [markdown]
# #### OBS: at this part all the parameters of decision variables and observed variables were defined. Now, it is necesary define a structure of the optimization network to have the capacity to generate whatever network of this kind of problem with the posibilty to change the number of variables, its limits, capacity of tanks and also the NUMBER of process and tanks

# %% [markdown]
# #### 1.4 Define models to load
# In this file are defined the path to ml models used in each process. Then reading the table the optimizer can go to load the ml model
#
# **As you can see a process can have multiple models because the process has multiple outputs. BUT each model to develop has its own and unique name**

# %%
#################### define initial values ####################

# paths and file names
path_folder_config_optimization = f'config/optimization_engine/config_optimization/'
file_modelsml = 'ModelsML.xlsx'
path_modelsml = path_folder_config_optimization + file_modelsml

# read file
config_modelsml = pd.read_excel(path_modelsml)

# table
config_modelsml
# Out:
#   process name_process_model   path_folder artifact_name
# 0    PR_A            PR_A_Y1     process_a     model.pkl
# 1    PR_B            PR_B_Y2  process_b_y2     model.pkl
# 2    PR_B            PR_B_Y3  process_b_y3     model.pkl
# 3    PR_C            PR_C_Y2     process_c    model.xlsx

# %% [markdown]
# #### 1.5 Map tanks
# Read a configuration table that map each tank in the process. For each tank is mapped the input flows and the output flows
#
# Important, obviosly, the input and outputs of the tank needs to be defined in the table that maps all the features in the network

# %%
#################### define map input outputs each tank ####################

# paths and file names
path_folder_config_optimization = f'config/optimization_engine/config_optimization/'
file_maptanks = 'MapTanks.xlsx'
path_maptanks = path_folder_config_optimization + file_maptanks

# read file
config_maptanks = pd.read_excel(path_maptanks)

# table
config_maptanks
# Out:
#    tank  tag feature_name input_output
# 0  TK_1   Y1           Y1           IN
# 1  TK_1   O4           O4           IN
# 2  TK_1   Z1           Z1          OUT
# 3  TK_1  TL1          TL1            L
# 4  TK_2   Y2           Y2           IN
# 5  TK_2  TL2          TL2            L
# 6  TK_3   Y3           Y3           IN
# 7  TK_3  TL3          TL3            L

# %% [markdown]
# #### 1.6 Map process Machine learning models features and target
# When each machine learning model is trained, one of the outputs of the tranining process is the artifact with the model and also a master table with the features and target of the model.
#
# - **In this example the individual master table for each model was generated in the training process and the global table is generated manually by the author**
#
# - **As you can see a process can have multiple models because the process has multiple outputs. BUT each model to develop has its own and unique name**

# %%
#################### define map features and targer of each model for each process ####################

# paths and file names
path_folder_config_optimization = f'config/optimization_engine/config_optimization/'
file_mapprocess_mlmodels = 'MapProcessMLmodels.xlsx'
path_mapprocess_mlmodels = path_folder_config_optimization + file_mapprocess_mlmodels

# read filemapprocess_mlmodels
config_mapprocess_mlmodels = pd.read_excel(path_mapprocess_mlmodels)

# table
config_mapprocess_mlmodels
# Out:
#    process name_process_model tag feature_name clasificacion
# 0     PR_A            PR_A_Y1  X1           X1             P
# 1     PR_A            PR_A_Y1  O1           O1             O
# 2     PR_A            PR_A_Y1  O2           O2             O
# 3     PR_A            PR_A_Y1  O3           O3             O
# 4     PR_A            PR_A_Y1  Y1           Y1             T
# 5     PR_B            PR_B_Y2  Z1           Z1             S
# 6     PR_B            PR_B_Y2  X2           X2             P
# 7     PR_B            PR_B_Y2  O5           O5             O
# 8     PR_B            PR_B_Y2  O6           O6             O
# 9     PR_B            PR_B_Y2  Y2           Y2             T
# 10    PR_B            PR_B_Y3  Z1           Z1             S
# 11    PR_B            PR_B_Y3  X2           X2             P
# 12    PR_B            PR_B_Y3  Y3           Y3             T
# 13    PR_C            PR_C_Y2  X3           X3             P
# 14    PR_C            PR_C_Y2  O7           O7             O
# 15    PR_C            PR_C_Y2  Y2           Y2             T

# %% [markdown]
# ### 2. Solve optimization
# Solve optimization relaxing constraints. In this example is relaxing the rate change of decision vars
#
# **In this first example, the rate change of decision vars are all relaxed and the unique rate change is the volume of tanks**

# %%
# define list of decision vars that will have change in its rate change
list_tags_to_relax_constraints = ['TL1', 'TL2', 'TL3']
list_tags_to_relax_constraints
# Out:
# ['TL1', 'TL2', 'TL3']

# %%
# define factor (percent = 0.1) to change the rate change of the decision vars. 
# In this example all the decision var masked will change its value in the same factor
param_factor_relax_constraints = 0.1
factor_relax_constraints = 1 + param_factor_relax_constraints
factor_relax_constraints
# Out:
# 1.1

# %%
# print initial values of constraints that can be relaxing its values
mask = config_allvariables['feature_name'].isin(list_tags_to_relax_constraints)
config_allvariables[mask]
# Out:
#     tag feature_name          description clasification_name clasification  \
# 14  TL1          TL1  Tank level - tank 1         Tank level             L
# 15  TL2          TL2  Tank level - tank 2         Tank level             L
# 16  TL3          TL3  Tank level - tank 3         Tank level             L
#
#     lower    upper  rate_change
# 14  100.0  20000.0         10.0
# 15  100.0  20000.0         10.0
# 16  100.0  20000.0         10.0

# %%
from optimization_engine import optimization_engine

# %%
""" do while. do define status solver // while status solver != 2 relaxing contrainsts (rate of change decision variables) until get a solution """
# initialize status
status_solver = 0

# initialize count iterations of relaxing constraints
index_count_while = 0
max_interations_relaxing_constraints = 40

# initiliaze values of constraints to relax
to_solver_config_allvariables = config_allvariables.copy()



while (status_solver != 2) & (index_count_while <=max_interations_relaxing_constraints):
    print('\n\n\n index while: ', index_count_while)

    ###### run optimization
    model_opt, status_solver, decision_var = optimization_engine(index_set_time,
                                    config_allvariables,
                                    config_initvalues,
                                    config_modelsml,
                                    config_maptanks,
                                    config_mapprocess_mlmodels,
                                    params)

    ##### get status solver - if solver get a solution - break the while
    if status_solver == 2:
        break
    
    # ###### relaxing constraints. if the solver return a value this values was delete, else the relaxing constraints are used in the while to get a solution
    # multiply rate change by factor of selected features
    mask = config_allvariables['feature_name'].isin(list_tags_to_relax_constraints)
    config_allvariables.loc[mask, 'rate_change'] = config_allvariables[mask]['rate_change'] * factor_relax_constraints

    # increse while
    index_count_while += 1
# Out:
#  index while:  0
#
# name model - model id:  PR_A_Y1
# path model loade:  process_a
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_a/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y2
# path model loade:  process_b_y2
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y2/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y3
# path model loade:  process_b_y3
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y3/model.pkl
# loaded pkl
#
# name model - model id:  PR_C_Y2
# path model loade:  process_c
# artifact model loaded:  model.xlsx
# full path model:  artifacts/models/process_c/model.xlsx
# loaded excel
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2441807
# WLS license 2441807 - registered to CMPC Celulosa S.A
# defining decision variables:  X1
# defining decision variables:  O1
# defining decision variables:  O2
# defining decision variables:  O3
# defining decision variables:  Y1
# defining decision variables:  O4
# defining decision variables:  Z1
# defining decision variables:  X2
# defining decision variables:  O5
# defining decision variables:  O6
# defining decision variables:  Y2
# defining decision variables:  Y3
# defining decision variables:  X3
# defining decision variables:  O7
# defining decision variables:  TL1
# defining decision variables:  TL2
# defining decision variables:  TL3
# set initial values decision variables: X1 ||| Initial value: 50.0
# set initial values decision variables: O1 ||| Initial value: 50.0
# set initial values decision variables: O2 ||| Initial value: 50.0
# set initial values decision variables: O3 ||| Initial value: 50.0
# set initial values decision variables: O4 ||| Initial value: 200.0
# set initial values decision variables: X2 ||| Initial value: 5.0
# set initial values decision variables: O5 ||| Initial value: 5.0
# set initial values decision variables: O6 ||| Initial value: 5.0
# set initial values decision variables: X3 ||| Initial value: 5.0
# set initial values decision variables: O7 ||| Initial value: 4.0
# set initial values decision variables: TL1 ||| Initial value: 500.0
# set initial values decision variables: TL2 ||| Initial value: 500.0
# set initial values decision variables: TL3 ||| Initial value: 500.0
# set lower bound decision variables: X1 ||| Lower bound: 0.0
# set lower bound decision variables: Y1 ||| Lower bound: 0.0
# set lower bound decision variables: Z1 ||| Lower bound: 0.0
# set lower bound decision variables: X2 ||| Lower bound: 0.0
# set lower bound decision variables: Y2 ||| Lower bound: 0.0
# set lower bound decision variables: Y3 ||| Lower bound: 0.0
# set lower bound decision variables: X3 ||| Lower bound: 0.0
# set lower bound decision variables: TL1 ||| Lower bound: 100.0
# set lower bound decision variables: TL2 ||| Lower bound: 100.0
# set lower bound decision variables: TL3 ||| Lower bound: 100.0
# set upper bound decision variables: X1 ||| Upper bound: 1000.0
# set upper bound decision variables: Y1 ||| Upper bound: 400.0
# set upper bound decision variables: Z1 ||| Upper bound: 1000.0
# set upper bound decision variables: X2 ||| Upper bound: 1000.0
# set upper bound decision variables: Y2 ||| Upper bound: 500.0
# set upper bound decision variables: Y3 ||| Upper bound: 450.0
# set upper bound decision variables: X3 ||| Upper bound: 1500.0
# set upper bound decision variables: TL1 ||| Upper bound: 20000.0
# set upper bound decision variables: TL2 ||| Upper bound: 20000.0
# set upper bound decision variables: TL3 ||| Upper bound: 20000.0
# create auxiliar variable diff "t" - "t-1":  X1
# create auxiliar variable diff "t" - "t-1":  Y1
# create auxiliar variable diff "t" - "t-1":  Z1
# create auxiliar variable diff "t" - "t-1":  X2
# create auxiliar variable diff "t" - "t-1":  Y2
# create auxiliar variable diff "t" - "t-1":  Y3
# create auxiliar variable diff "t" - "t-1":  X3
# create auxiliar variable diff "t" - "t-1":  TL1
# create auxiliar variable diff "t" - "t-1":  TL2
# create auxiliar variable diff "t" - "t-1":  TL3
# rate change decision var:  X1
# rate change decision var:  Y1
# rate change decision var:  Z1
# rate change decision var:  X2
# rate change decision var:  Y2
# rate change decision var:  Y3
# rate change decision var:  X3
# rate change decision var:  TL1
# rate change decision var:  TL2
# rate change decision var:  TL3
# tank name:  TK_1
# tank name:  TK_2
# tank name:  TK_3
# set fixed value observed values: O1 ||| Fixed value observed: 50.0
# set fixed value observed values: O2 ||| Fixed value observed: 50.0
# set fixed value observed values: O3 ||| Fixed value observed: 50.0
# set fixed value observed values: O4 ||| Fixed value observed: 200.0
# set fixed value observed values: O5 ||| Fixed value observed: 5.0
# set fixed value observed values: O6 ||| Fixed value observed: 5.0
# set fixed value observed values: O7 ||| Fixed value observed: 4.0
#
# name model - model id:  PR_A_Y1
# constraint machine learning model
#
# name model - model id:  PR_B_Y2
# constraint machine learning model
#
# name model - model id:  PR_B_Y3
# constraint machine learning model
#
# name model - model id:  PR_C_Y2
# constraint custom model
# decision var:  X3
# decision var:  O7
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19043.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# WLS license 2441807 - registered to CMPC Celulosa S.A
# Optimize a model with 508 rows, 259 columns and 950 nonzeros
# Model fingerprint: 0x20a30b35
# Coefficient statistics:
#   Matrix range     [2e-01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+04]
# Presolve removed 336 rows and 169 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible or unbounded model
# There was a problem - infeasible solution
#
#
#
#  index while:  1
#
# name model - model id:  PR_A_Y1
# path model loade:  process_a
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_a/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y2
# path model loade:  process_b_y2
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y2/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y3
# path model loade:  process_b_y3
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y3/model.pkl
# loaded pkl
#
# name model - model id:  PR_C_Y2
# path model loade:  process_c
# artifact model loaded:  model.xlsx
# full path model:  artifacts/models/process_c/model.xlsx
# loaded excel
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2441807
# WLS license 2441807 - registered to CMPC Celulosa S.A
# defining decision variables:  X1
# defining decision variables:  O1
# defining decision variables:  O2
# defining decision variables:  O3
# defining decision variables:  Y1
# defining decision variables:  O4
# defining decision variables:  Z1
# defining decision variables:  X2
# defining decision variables:  O5
# defining decision variables:  O6
# defining decision variables:  Y2
# defining decision variables:  Y3
# defining decision variables:  X3
# defining decision variables:  O7
# defining decision variables:  TL1
# defining decision variables:  TL2
# defining decision variables:  TL3
# set initial values decision variables: X1 ||| Initial value: 50.0
# set initial values decision variables: O1 ||| Initial value: 50.0
# set initial values decision variables: O2 ||| Initial value: 50.0
# set initial values decision variables: O3 ||| Initial value: 50.0
# set initial values decision variables: O4 ||| Initial value: 200.0
# set initial values decision variables: X2 ||| Initial value: 5.0
# set initial values decision variables: O5 ||| Initial value: 5.0
# set initial values decision variables: O6 ||| Initial value: 5.0
# set initial values decision variables: X3 ||| Initial value: 5.0
# set initial values decision variables: O7 ||| Initial value: 4.0
# set initial values decision variables: TL1 ||| Initial value: 500.0
# set initial values decision variables: TL2 ||| Initial value: 500.0
# set initial values decision variables: TL3 ||| Initial value: 500.0
# set lower bound decision variables: X1 ||| Lower bound: 0.0
# set lower bound decision variables: Y1 ||| Lower bound: 0.0
# set lower bound decision variables: Z1 ||| Lower bound: 0.0
# set lower bound decision variables: X2 ||| Lower bound: 0.0
# set lower bound decision variables: Y2 ||| Lower bound: 0.0
# set lower bound decision variables: Y3 ||| Lower bound: 0.0
# set lower bound decision variables: X3 ||| Lower bound: 0.0
# set lower bound decision variables: TL1 ||| Lower bound: 100.0
# set lower bound decision variables: TL2 ||| Lower bound: 100.0
# set lower bound decision variables: TL3 ||| Lower bound: 100.0
# set upper bound decision variables: X1 ||| Upper bound: 1000.0
# set upper bound decision variables: Y1 ||| Upper bound: 400.0
# set upper bound decision variables: Z1 ||| Upper bound: 1000.0
# set upper bound decision variables: X2 ||| Upper bound: 1000.0
# set upper bound decision variables: Y2 ||| Upper bound: 500.0
# set upper bound decision variables: Y3 ||| Upper bound: 450.0
# set upper bound decision variables: X3 ||| Upper bound: 1500.0
# set upper bound decision variables: TL1 ||| Upper bound: 20000.0
# set upper bound decision variables: TL2 ||| Upper bound: 20000.0
# set upper bound decision variables: TL3 ||| Upper bound: 20000.0
# create auxiliar variable diff "t" - "t-1":  X1
# create auxiliar variable diff "t" - "t-1":  Y1
# create auxiliar variable diff "t" - "t-1":  Z1
# create auxiliar variable diff "t" - "t-1":  X2
# create auxiliar variable diff "t" - "t-1":  Y2
# create auxiliar variable diff "t" - "t-1":  Y3
# create auxiliar variable diff "t" - "t-1":  X3
# create auxiliar variable diff "t" - "t-1":  TL1
# create auxiliar variable diff "t" - "t-1":  TL2
# create auxiliar variable diff "t" - "t-1":  TL3
# rate change decision var:  X1
# rate change decision var:  Y1
# rate change decision var:  Z1
# rate change decision var:  X2
# rate change decision var:  Y2
# rate change decision var:  Y3
# rate change decision var:  X3
# rate change decision var:  TL1
# rate change decision var:  TL2
# rate change decision var:  TL3
# tank name:  TK_1
# tank name:  TK_2
# tank name:  TK_3
# set fixed value observed values: O1 ||| Fixed value observed: 50.0
# set fixed value observed values: O2 ||| Fixed value observed: 50.0
# set fixed value observed values: O3 ||| Fixed value observed: 50.0
# set fixed value observed values: O4 ||| Fixed value observed: 200.0
# set fixed value observed values: O5 ||| Fixed value observed: 5.0
# set fixed value observed values: O6 ||| Fixed value observed: 5.0
# set fixed value observed values: O7 ||| Fixed value observed: 4.0
#
# name model - model id:  PR_A_Y1
# constraint machine learning model
#
# name model - model id:  PR_B_Y2
# constraint machine learning model
#
# name model - model id:  PR_B_Y3
# constraint machine learning model
#
# name model - model id:  PR_C_Y2
# constraint custom model
# decision var:  X3
# decision var:  O7
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19043.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# WLS license 2441807 - registered to CMPC Celulosa S.A
# Optimize a model with 508 rows, 259 columns and 950 nonzeros
# Model fingerprint: 0x05b7cf03
# Coefficient statistics:
#   Matrix range     [2e-01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+04]
# Presolve removed 336 rows and 169 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible or unbounded model
# There was a problem - infeasible solution
#
#
#
#  index while:  2
#
# name model - model id:  PR_A_Y1
# path model loade:  process_a
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_a/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y2
# path model loade:  process_b_y2
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y2/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y3
# path model loade:  process_b_y3
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y3/model.pkl
# loaded pkl
#
# name model - model id:  PR_C_Y2
# path model loade:  process_c
# artifact model loaded:  model.xlsx
# full path model:  artifacts/models/process_c/model.xlsx
# loaded excel
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2441807
# WLS license 2441807 - registered to CMPC Celulosa S.A
# defining decision variables:  X1
# defining decision variables:  O1
# defining decision variables:  O2
# defining decision variables:  O3
# defining decision variables:  Y1
# defining decision variables:  O4
# defining decision variables:  Z1
# defining decision variables:  X2
# defining decision variables:  O5
# Warning: environment still referenced so free is deferred (Continue to use WLS)
# defining decision variables:  O6
# defining decision variables:  Y2
# defining decision variables:  Y3
# defining decision variables:  X3
# defining decision variables:  O7
# defining decision variables:  TL1
# defining decision variables:  TL2
# defining decision variables:  TL3
# set initial values decision variables: X1 ||| Initial value: 50.0
# set initial values decision variables: O1 ||| Initial value: 50.0
# set initial values decision variables: O2 ||| Initial value: 50.0
# set initial values decision variables: O3 ||| Initial value: 50.0
# set initial values decision variables: O4 ||| Initial value: 200.0
# set initial values decision variables: X2 ||| Initial value: 5.0
# set initial values decision variables: O5 ||| Initial value: 5.0
# set initial values decision variables: O6 ||| Initial value: 5.0
# set initial values decision variables: X3 ||| Initial value: 5.0
# set initial values decision variables: O7 ||| Initial value: 4.0
# set initial values decision variables: TL1 ||| Initial value: 500.0
# set initial values decision variables: TL2 ||| Initial value: 500.0
# set initial values decision variables: TL3 ||| Initial value: 500.0
# set lower bound decision variables: X1 ||| Lower bound: 0.0
# set lower bound decision variables: Y1 ||| Lower bound: 0.0
# set lower bound decision variables: Z1 ||| Lower bound: 0.0
# set lower bound decision variables: X2 ||| Lower bound: 0.0
# set lower bound decision variables: Y2 ||| Lower bound: 0.0
# set lower bound decision variables: Y3 ||| Lower bound: 0.0
# set lower bound decision variables: X3 ||| Lower bound: 0.0
# set lower bound decision variables: TL1 ||| Lower bound: 100.0
# set lower bound decision variables: TL2 ||| Lower bound: 100.0
# set lower bound decision variables: TL3 ||| Lower bound: 100.0
# set upper bound decision variables: X1 ||| Upper bound: 1000.0
# set upper bound decision variables: Y1 ||| Upper bound: 400.0
# set upper bound decision variables: Z1 ||| Upper bound: 1000.0
# set upper bound decision variables: X2 ||| Upper bound: 1000.0
# set upper bound decision variables: Y2 ||| Upper bound: 500.0
# set upper bound decision variables: Y3 ||| Upper bound: 450.0
# set upper bound decision variables: X3 ||| Upper bound: 1500.0
# set upper bound decision variables: TL1 ||| Upper bound: 20000.0
# set upper bound decision variables: TL2 ||| Upper bound: 20000.0
# set upper bound decision variables: TL3 ||| Upper bound: 20000.0
# create auxiliar variable diff "t" - "t-1":  X1
# create auxiliar variable diff "t" - "t-1":  Y1
# create auxiliar variable diff "t" - "t-1":  Z1
# create auxiliar variable diff "t" - "t-1":  X2
# create auxiliar variable diff "t" - "t-1":  Y2
# create auxiliar variable diff "t" - "t-1":  Y3
# create auxiliar variable diff "t" - "t-1":  X3
# create auxiliar variable diff "t" - "t-1":  TL1
# create auxiliar variable diff "t" - "t-1":  TL2
# create auxiliar variable diff "t" - "t-1":  TL3
# rate change decision var:  X1
# rate change decision var:  Y1
# rate change decision var:  Z1
# rate change decision var:  X2
# rate change decision var:  Y2
# rate change decision var:  Y3
# rate change decision var:  X3
# rate change decision var:  TL1
# rate change decision var:  TL2
# rate change decision var:  TL3
# tank name:  TK_1
# tank name:  TK_2
# tank name:  TK_3
# set fixed value observed values: O1 ||| Fixed value observed: 50.0
# set fixed value observed values: O2 ||| Fixed value observed: 50.0
# set fixed value observed values: O3 ||| Fixed value observed: 50.0
# set fixed value observed values: O4 ||| Fixed value observed: 200.0
# set fixed value observed values: O5 ||| Fixed value observed: 5.0
# set fixed value observed values: O6 ||| Fixed value observed: 5.0
# set fixed value observed values: O7 ||| Fixed value observed: 4.0
#
# name model - model id:  PR_A_Y1
# constraint machine learning model
#
# name model - model id:  PR_B_Y2
# constraint machine learning model
#
# name model - model id:  PR_B_Y3
# constraint machine learning model
#
# name model - model id:  PR_C_Y2
# constraint custom model
# decision var:  X3
# decision var:  O7
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19043.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# WLS license 2441807 - registered to CMPC Celulosa S.A
# Optimize a model with 508 rows, 259 columns and 950 nonzeros
# Model fingerprint: 0x8e459697
# Coefficient statistics:
#   Matrix range     [2e-01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+04]
# Presolve removed 336 rows and 169 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible or unbounded model
# There was a problem - infeasible solution
#
#
#
#  index while:  3
#
# name model - model id:  PR_A_Y1
# path model loade:  process_a
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_a/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y2
# path model loade:  process_b_y2
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y2/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y3
# path model loade:  process_b_y3
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y3/model.pkl
# loaded pkl
#
# name model - model id:  PR_C_Y2
# path model loade:  process_c
# artifact model loaded:  model.xlsx
# full path model:  artifacts/models/process_c/model.xlsx
# loaded excel
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2441807
# WLS license 2441807 - registered to CMPC Celulosa S.A
# defining decision variables:  X1
# defining decision variables:  O1
# defining decision variables:  O2
# defining decision variables:  O3
# defining decision variables:  Y1
# defining decision variables:  O4
# defining decision variables:  Z1
# defining decision variables:  X2
# defining decision variables:  O5
# defining decision variables:  O6
# defining decision variables:  Y2
# defining decision variables:  Y3
# defining decision variables:  X3
# defining decision variables:  O7
# defining decision variables:  TL1
# defining decision variables:  TL2
# defining decision variables:  TL3
# set initial values decision variables: X1 ||| Initial value: 50.0
# set initial values decision variables: O1 ||| Initial value: 50.0
# set initial values decision variables: O2 ||| Initial value: 50.0
# set initial values decision variables: O3 ||| Initial value: 50.0
# set initial values decision variables: O4 ||| Initial value: 200.0
# set initial values decision variables: X2 ||| Initial value: 5.0
# set initial values decision variables: O5 ||| Initial value: 5.0
# set initial values decision variables: O6 ||| Initial value: 5.0
# set initial values decision variables: X3 ||| Initial value: 5.0
# set initial values decision variables: O7 ||| Initial value: 4.0
# set initial values decision variables: TL1 ||| Initial value: 500.0
# set initial values decision variables: TL2 ||| Initial value: 500.0
# set initial values decision variables: TL3 ||| Initial value: 500.0
# set lower bound decision variables: X1 ||| Lower bound: 0.0
# set lower bound decision variables: Y1 ||| Lower bound: 0.0
# set lower bound decision variables: Z1 ||| Lower bound: 0.0
# set lower bound decision variables: X2 ||| Lower bound: 0.0
# set lower bound decision variables: Y2 ||| Lower bound: 0.0
# set lower bound decision variables: Y3 ||| Lower bound: 0.0
# set lower bound decision variables: X3 ||| Lower bound: 0.0
# set lower bound decision variables: TL1 ||| Lower bound: 100.0
# set lower bound decision variables: TL2 ||| Lower bound: 100.0
# set lower bound decision variables: TL3 ||| Lower bound: 100.0
# set upper bound decision variables: X1 ||| Upper bound: 1000.0
# set upper bound decision variables: Y1 ||| Upper bound: 400.0
# set upper bound decision variables: Z1 ||| Upper bound: 1000.0
# set upper bound decision variables: X2 ||| Upper bound: 1000.0
# set upper bound decision variables: Y2 ||| Upper bound: 500.0
# set upper bound decision variables: Y3 ||| Upper bound: 450.0
# set upper bound decision variables: X3 ||| Upper bound: 1500.0
# set upper bound decision variables: TL1 ||| Upper bound: 20000.0
# set upper bound decision variables: TL2 ||| Upper bound: 20000.0
# set upper bound decision variables: TL3 ||| Upper bound: 20000.0
# create auxiliar variable diff "t" - "t-1":  X1
# create auxiliar variable diff "t" - "t-1":  Y1
# create auxiliar variable diff "t" - "t-1":  Z1
# create auxiliar variable diff "t" - "t-1":  X2
# create auxiliar variable diff "t" - "t-1":  Y2
# create auxiliar variable diff "t" - "t-1":  Y3
# create auxiliar variable diff "t" - "t-1":  X3
# create auxiliar variable diff "t" - "t-1":  TL1
# create auxiliar variable diff "t" - "t-1":  TL2
# create auxiliar variable diff "t" - "t-1":  TL3
# rate change decision var:  X1
# rate change decision var:  Y1
# rate change decision var:  Z1
# rate change decision var:  X2
# rate change decision var:  Y2
# rate change decision var:  Y3
# rate change decision var:  X3
# rate change decision var:  TL1
# rate change decision var:  TL2
# rate change decision var:  TL3
# tank name:  TK_1
# tank name:  TK_2
# tank name:  TK_3
# set fixed value observed values: O1 ||| Fixed value observed: 50.0
# set fixed value observed values: O2 ||| Fixed value observed: 50.0
# set fixed value observed values: O3 ||| Fixed value observed: 50.0
# set fixed value observed values: O4 ||| Fixed value observed: 200.0
# set fixed value observed values: O5 ||| Fixed value observed: 5.0
# set fixed value observed values: O6 ||| Fixed value observed: 5.0
# set fixed value observed values: O7 ||| Fixed value observed: 4.0
#
# name model - model id:  PR_A_Y1
# constraint machine learning model
#
# name model - model id:  PR_B_Y2
# constraint machine learning model
#
# name model - model id:  PR_B_Y3
# constraint machine learning model
#
# name model - model id:  PR_C_Y2
# constraint custom model
# decision var:  X3
# decision var:  O7
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19043.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# WLS license 2441807 - registered to CMPC Celulosa S.A
# Optimize a model with 508 rows, 259 columns and 950 nonzeros
# Model fingerprint: 0x4cf12a7d
# Coefficient statistics:
#   Matrix range     [2e-01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+04]
# Presolve removed 336 rows and 169 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible or unbounded model
# There was a problem - infeasible solution
#
#
#
#  index while:  4
#
# name model - model id:  PR_A_Y1
# path model loade:  process_a
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_a/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y2
# path model loade:  process_b_y2
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y2/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y3
# path model loade:  process_b_y3
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y3/model.pkl
# loaded pkl
#
# name model - model id:  PR_C_Y2
# path model loade:  process_c
# artifact model loaded:  model.xlsx
# full path model:  artifacts/models/process_c/model.xlsx
# loaded excel
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2441807
# WLS license 2441807 - registered to CMPC Celulosa S.A
# defining decision variables:  X1
# defining decision variables:  O1
# defining decision variables:  O2
# defining decision variables:  O3
# defining decision variables:  Y1
# defining decision variables:  O4
# defining decision variables:  Z1
# defining decision variables:  X2
# defining decision variables:  O5
# Warning: environment still referenced so free is deferred (Continue to use WLS)
# defining decision variables:  O6
# defining decision variables:  Y2
# defining decision variables:  Y3
# defining decision variables:  X3
# defining decision variables:  O7
# defining decision variables:  TL1
# defining decision variables:  TL2
# defining decision variables:  TL3
# set initial values decision variables: X1 ||| Initial value: 50.0
# set initial values decision variables: O1 ||| Initial value: 50.0
# set initial values decision variables: O2 ||| Initial value: 50.0
# set initial values decision variables: O3 ||| Initial value: 50.0
# set initial values decision variables: O4 ||| Initial value: 200.0
# set initial values decision variables: X2 ||| Initial value: 5.0
# set initial values decision variables: O5 ||| Initial value: 5.0
# set initial values decision variables: O6 ||| Initial value: 5.0
# set initial values decision variables: X3 ||| Initial value: 5.0
# set initial values decision variables: O7 ||| Initial value: 4.0
# set initial values decision variables: TL1 ||| Initial value: 500.0
# set initial values decision variables: TL2 ||| Initial value: 500.0
# set initial values decision variables: TL3 ||| Initial value: 500.0
# set lower bound decision variables: X1 ||| Lower bound: 0.0
# set lower bound decision variables: Y1 ||| Lower bound: 0.0
# set lower bound decision variables: Z1 ||| Lower bound: 0.0
# set lower bound decision variables: X2 ||| Lower bound: 0.0
# set lower bound decision variables: Y2 ||| Lower bound: 0.0
# set lower bound decision variables: Y3 ||| Lower bound: 0.0
# set lower bound decision variables: X3 ||| Lower bound: 0.0
# set lower bound decision variables: TL1 ||| Lower bound: 100.0
# set lower bound decision variables: TL2 ||| Lower bound: 100.0
# set lower bound decision variables: TL3 ||| Lower bound: 100.0
# set upper bound decision variables: X1 ||| Upper bound: 1000.0
# set upper bound decision variables: Y1 ||| Upper bound: 400.0
# set upper bound decision variables: Z1 ||| Upper bound: 1000.0
# set upper bound decision variables: X2 ||| Upper bound: 1000.0
# set upper bound decision variables: Y2 ||| Upper bound: 500.0
# set upper bound decision variables: Y3 ||| Upper bound: 450.0
# set upper bound decision variables: X3 ||| Upper bound: 1500.0
# set upper bound decision variables: TL1 ||| Upper bound: 20000.0
# set upper bound decision variables: TL2 ||| Upper bound: 20000.0
# set upper bound decision variables: TL3 ||| Upper bound: 20000.0
# create auxiliar variable diff "t" - "t-1":  X1
# create auxiliar variable diff "t" - "t-1":  Y1
# create auxiliar variable diff "t" - "t-1":  Z1
# create auxiliar variable diff "t" - "t-1":  X2
# create auxiliar variable diff "t" - "t-1":  Y2
# create auxiliar variable diff "t" - "t-1":  Y3
# create auxiliar variable diff "t" - "t-1":  X3
# create auxiliar variable diff "t" - "t-1":  TL1
# create auxiliar variable diff "t" - "t-1":  TL2
# create auxiliar variable diff "t" - "t-1":  TL3
# rate change decision var:  X1
# rate change decision var:  Y1
# rate change decision var:  Z1
# rate change decision var:  X2
# rate change decision var:  Y2
# rate change decision var:  Y3
# rate change decision var:  X3
# rate change decision var:  TL1
# rate change decision var:  TL2
# rate change decision var:  TL3
# tank name:  TK_1
# tank name:  TK_2
# tank name:  TK_3
# set fixed value observed values: O1 ||| Fixed value observed: 50.0
# set fixed value observed values: O2 ||| Fixed value observed: 50.0
# set fixed value observed values: O3 ||| Fixed value observed: 50.0
# set fixed value observed values: O4 ||| Fixed value observed: 200.0
# set fixed value observed values: O5 ||| Fixed value observed: 5.0
# set fixed value observed values: O6 ||| Fixed value observed: 5.0
# set fixed value observed values: O7 ||| Fixed value observed: 4.0
#
# name model - model id:  PR_A_Y1
# constraint machine learning model
#
# name model - model id:  PR_B_Y2
# constraint machine learning model
#
# name model - model id:  PR_B_Y3
# constraint machine learning model
#
# name model - model id:  PR_C_Y2
# constraint custom model
# decision var:  X3
# decision var:  O7
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19043.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# WLS license 2441807 - registered to CMPC Celulosa S.A
# Optimize a model with 508 rows, 259 columns and 950 nonzeros
# Model fingerprint: 0xbfb3c434
# Coefficient statistics:
#   Matrix range     [2e-01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+04]
# Presolve removed 336 rows and 169 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible or unbounded model
# There was a problem - infeasible solution
#
#
#
#  index while:  5
#
# name model - model id:  PR_A_Y1
# path model loade:  process_a
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_a/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y2
# path model loade:  process_b_y2
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y2/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y3
# path model loade:  process_b_y3
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y3/model.pkl
# loaded pkl
#
# name model - model id:  PR_C_Y2
# path model loade:  process_c
# artifact model loaded:  model.xlsx
# full path model:  artifacts/models/process_c/model.xlsx
# loaded excel
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2441807
# WLS license 2441807 - registered to CMPC Celulosa S.A
# defining decision variables:  X1
# defining decision variables:  O1
# defining decision variables:  O2
# defining decision variables:  O3
# defining decision variables:  Y1
# defining decision variables:  O4
# defining decision variables:  Z1
# defining decision variables:  X2
# defining decision variables:  O5
# defining decision variables:  O6
# defining decision variables:  Y2
# defining decision variables:  Y3
# defining decision variables:  X3
# defining decision variables:  O7
# defining decision variables:  TL1
# defining decision variables:  TL2
# defining decision variables:  TL3
# set initial values decision variables: X1 ||| Initial value: 50.0
# set initial values decision variables: O1 ||| Initial value: 50.0
# set initial values decision variables: O2 ||| Initial value: 50.0
# set initial values decision variables: O3 ||| Initial value: 50.0
# set initial values decision variables: O4 ||| Initial value: 200.0
# set initial values decision variables: X2 ||| Initial value: 5.0
# set initial values decision variables: O5 ||| Initial value: 5.0
# set initial values decision variables: O6 ||| Initial value: 5.0
# set initial values decision variables: X3 ||| Initial value: 5.0
# set initial values decision variables: O7 ||| Initial value: 4.0
# set initial values decision variables: TL1 ||| Initial value: 500.0
# set initial values decision variables: TL2 ||| Initial value: 500.0
# set initial values decision variables: TL3 ||| Initial value: 500.0
# set lower bound decision variables: X1 ||| Lower bound: 0.0
# set lower bound decision variables: Y1 ||| Lower bound: 0.0
# set lower bound decision variables: Z1 ||| Lower bound: 0.0
# set lower bound decision variables: X2 ||| Lower bound: 0.0
# set lower bound decision variables: Y2 ||| Lower bound: 0.0
# set lower bound decision variables: Y3 ||| Lower bound: 0.0
# set lower bound decision variables: X3 ||| Lower bound: 0.0
# set lower bound decision variables: TL1 ||| Lower bound: 100.0
# set lower bound decision variables: TL2 ||| Lower bound: 100.0
# set lower bound decision variables: TL3 ||| Lower bound: 100.0
# set upper bound decision variables: X1 ||| Upper bound: 1000.0
# set upper bound decision variables: Y1 ||| Upper bound: 400.0
# set upper bound decision variables: Z1 ||| Upper bound: 1000.0
# set upper bound decision variables: X2 ||| Upper bound: 1000.0
# set upper bound decision variables: Y2 ||| Upper bound: 500.0
# set upper bound decision variables: Y3 ||| Upper bound: 450.0
# set upper bound decision variables: X3 ||| Upper bound: 1500.0
# set upper bound decision variables: TL1 ||| Upper bound: 20000.0
# set upper bound decision variables: TL2 ||| Upper bound: 20000.0
# set upper bound decision variables: TL3 ||| Upper bound: 20000.0
# create auxiliar variable diff "t" - "t-1":  X1
# create auxiliar variable diff "t" - "t-1":  Y1
# create auxiliar variable diff "t" - "t-1":  Z1
# create auxiliar variable diff "t" - "t-1":  X2
# create auxiliar variable diff "t" - "t-1":  Y2
# create auxiliar variable diff "t" - "t-1":  Y3
# create auxiliar variable diff "t" - "t-1":  X3
# create auxiliar variable diff "t" - "t-1":  TL1
# create auxiliar variable diff "t" - "t-1":  TL2
# create auxiliar variable diff "t" - "t-1":  TL3
# rate change decision var:  X1
# rate change decision var:  Y1
# rate change decision var:  Z1
# rate change decision var:  X2
# rate change decision var:  Y2
# rate change decision var:  Y3
# rate change decision var:  X3
# rate change decision var:  TL1
# rate change decision var:  TL2
# rate change decision var:  TL3
# tank name:  TK_1
# tank name:  TK_2
# tank name:  TK_3
# set fixed value observed values: O1 ||| Fixed value observed: 50.0
# set fixed value observed values: O2 ||| Fixed value observed: 50.0
# set fixed value observed values: O3 ||| Fixed value observed: 50.0
# set fixed value observed values: O4 ||| Fixed value observed: 200.0
# set fixed value observed values: O5 ||| Fixed value observed: 5.0
# set fixed value observed values: O6 ||| Fixed value observed: 5.0
# set fixed value observed values: O7 ||| Fixed value observed: 4.0
#
# name model - model id:  PR_A_Y1
# constraint machine learning model
#
# name model - model id:  PR_B_Y2
# constraint machine learning model
#
# name model - model id:  PR_B_Y3
# constraint machine learning model
#
# name model - model id:  PR_C_Y2
# constraint custom model
# decision var:  X3
# decision var:  O7
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19043.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# WLS license 2441807 - registered to CMPC Celulosa S.A
# Optimize a model with 508 rows, 259 columns and 950 nonzeros
# Model fingerprint: 0x4018ea10
# Coefficient statistics:
#   Matrix range     [2e-01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+04]
# Presolve removed 336 rows and 169 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible or unbounded model
# There was a problem - infeasible solution
#
#
#
#  index while:  6
#
# name model - model id:  PR_A_Y1
# path model loade:  process_a
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_a/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y2
# path model loade:  process_b_y2
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y2/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y3
# path model loade:  process_b_y3
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y3/model.pkl
# loaded pkl
#
# name model - model id:  PR_C_Y2
# path model loade:  process_c
# artifact model loaded:  model.xlsx
# full path model:  artifacts/models/process_c/model.xlsx
# loaded excel
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2441807
# WLS license 2441807 - registered to CMPC Celulosa S.A
# defining decision variables:  X1
# defining decision variables:  O1
# defining decision variables:  O2
# defining decision variables:  O3
# defining decision variables:  Y1
# defining decision variables:  O4
# defining decision variables:  Z1
# defining decision variables:  X2
# defining decision variables:  O5
# defining decision variables:  O6
# Warning: environment still referenced so free is deferred (Continue to use WLS)
# defining decision variables:  Y2
# defining decision variables:  Y3
# defining decision variables:  X3
# defining decision variables:  O7
# defining decision variables:  TL1
# defining decision variables:  TL2
# defining decision variables:  TL3
# set initial values decision variables: X1 ||| Initial value: 50.0
# set initial values decision variables: O1 ||| Initial value: 50.0
# set initial values decision variables: O2 ||| Initial value: 50.0
# set initial values decision variables: O3 ||| Initial value: 50.0
# set initial values decision variables: O4 ||| Initial value: 200.0
# set initial values decision variables: X2 ||| Initial value: 5.0
# set initial values decision variables: O5 ||| Initial value: 5.0
# set initial values decision variables: O6 ||| Initial value: 5.0
# set initial values decision variables: X3 ||| Initial value: 5.0
# set initial values decision variables: O7 ||| Initial value: 4.0
# set initial values decision variables: TL1 ||| Initial value: 500.0
# set initial values decision variables: TL2 ||| Initial value: 500.0
# set initial values decision variables: TL3 ||| Initial value: 500.0
# set lower bound decision variables: X1 ||| Lower bound: 0.0
# set lower bound decision variables: Y1 ||| Lower bound: 0.0
# set lower bound decision variables: Z1 ||| Lower bound: 0.0
# set lower bound decision variables: X2 ||| Lower bound: 0.0
# set lower bound decision variables: Y2 ||| Lower bound: 0.0
# set lower bound decision variables: Y3 ||| Lower bound: 0.0
# set lower bound decision variables: X3 ||| Lower bound: 0.0
# set lower bound decision variables: TL1 ||| Lower bound: 100.0
# set lower bound decision variables: TL2 ||| Lower bound: 100.0
# set lower bound decision variables: TL3 ||| Lower bound: 100.0
# set upper bound decision variables: X1 ||| Upper bound: 1000.0
# set upper bound decision variables: Y1 ||| Upper bound: 400.0
# set upper bound decision variables: Z1 ||| Upper bound: 1000.0
# set upper bound decision variables: X2 ||| Upper bound: 1000.0
# set upper bound decision variables: Y2 ||| Upper bound: 500.0
# set upper bound decision variables: Y3 ||| Upper bound: 450.0
# set upper bound decision variables: X3 ||| Upper bound: 1500.0
# set upper bound decision variables: TL1 ||| Upper bound: 20000.0
# set upper bound decision variables: TL2 ||| Upper bound: 20000.0
# set upper bound decision variables: TL3 ||| Upper bound: 20000.0
# create auxiliar variable diff "t" - "t-1":  X1
# create auxiliar variable diff "t" - "t-1":  Y1
# create auxiliar variable diff "t" - "t-1":  Z1
# create auxiliar variable diff "t" - "t-1":  X2
# create auxiliar variable diff "t" - "t-1":  Y2
# create auxiliar variable diff "t" - "t-1":  Y3
# create auxiliar variable diff "t" - "t-1":  X3
# create auxiliar variable diff "t" - "t-1":  TL1
# create auxiliar variable diff "t" - "t-1":  TL2
# create auxiliar variable diff "t" - "t-1":  TL3
# rate change decision var:  X1
# rate change decision var:  Y1
# rate change decision var:  Z1
# rate change decision var:  X2
# rate change decision var:  Y2
# rate change decision var:  Y3
# rate change decision var:  X3
# rate change decision var:  TL1
# rate change decision var:  TL2
# rate change decision var:  TL3
# tank name:  TK_1
# tank name:  TK_2
# tank name:  TK_3
# set fixed value observed values: O1 ||| Fixed value observed: 50.0
# set fixed value observed values: O2 ||| Fixed value observed: 50.0
# set fixed value observed values: O3 ||| Fixed value observed: 50.0
# set fixed value observed values: O4 ||| Fixed value observed: 200.0
# set fixed value observed values: O5 ||| Fixed value observed: 5.0
# set fixed value observed values: O6 ||| Fixed value observed: 5.0
# set fixed value observed values: O7 ||| Fixed value observed: 4.0
#
# name model - model id:  PR_A_Y1
# constraint machine learning model
#
# name model - model id:  PR_B_Y2
# constraint machine learning model
#
# name model - model id:  PR_B_Y3
# constraint machine learning model
#
# name model - model id:  PR_C_Y2
# constraint custom model
# decision var:  X3
# decision var:  O7
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19043.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# WLS license 2441807 - registered to CMPC Celulosa S.A
# Optimize a model with 508 rows, 259 columns and 950 nonzeros
# Model fingerprint: 0x94d4a7eb
# Coefficient statistics:
#   Matrix range     [2e-01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+04]
# Presolve removed 336 rows and 169 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible or unbounded model
# There was a problem - infeasible solution
#
#
#
#  index while:  7
#
# name model - model id:  PR_A_Y1
# path model loade:  process_a
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_a/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y2
# path model loade:  process_b_y2
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y2/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y3
# path model loade:  process_b_y3
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y3/model.pkl
# loaded pkl
#
# name model - model id:  PR_C_Y2
# path model loade:  process_c
# artifact model loaded:  model.xlsx
# full path model:  artifacts/models/process_c/model.xlsx
# loaded excel
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2441807
# WLS license 2441807 - registered to CMPC Celulosa S.A
# defining decision variables:  X1
# defining decision variables:  O1
# defining decision variables:  O2
# defining decision variables:  O3
# defining decision variables:  Y1
# defining decision variables:  O4
# defining decision variables:  Z1
# defining decision variables:  X2
# defining decision variables:  O5
# defining decision variables:  O6
# defining decision variables:  Y2
# defining decision variables:  Y3
# defining decision variables:  X3
# defining decision variables:  O7
# defining decision variables:  TL1
# defining decision variables:  TL2
# defining decision variables:  TL3
# set initial values decision variables: X1 ||| Initial value: 50.0
# set initial values decision variables: O1 ||| Initial value: 50.0
# set initial values decision variables: O2 ||| Initial value: 50.0
# set initial values decision variables: O3 ||| Initial value: 50.0
# set initial values decision variables: O4 ||| Initial value: 200.0
# set initial values decision variables: X2 ||| Initial value: 5.0
# set initial values decision variables: O5 ||| Initial value: 5.0
# set initial values decision variables: O6 ||| Initial value: 5.0
# set initial values decision variables: X3 ||| Initial value: 5.0
# set initial values decision variables: O7 ||| Initial value: 4.0
# set initial values decision variables: TL1 ||| Initial value: 500.0
# set initial values decision variables: TL2 ||| Initial value: 500.0
# set initial values decision variables: TL3 ||| Initial value: 500.0
# set lower bound decision variables: X1 ||| Lower bound: 0.0
# set lower bound decision variables: Y1 ||| Lower bound: 0.0
# set lower bound decision variables: Z1 ||| Lower bound: 0.0
# set lower bound decision variables: X2 ||| Lower bound: 0.0
# set lower bound decision variables: Y2 ||| Lower bound: 0.0
# set lower bound decision variables: Y3 ||| Lower bound: 0.0
# set lower bound decision variables: X3 ||| Lower bound: 0.0
# set lower bound decision variables: TL1 ||| Lower bound: 100.0
# set lower bound decision variables: TL2 ||| Lower bound: 100.0
# set lower bound decision variables: TL3 ||| Lower bound: 100.0
# set upper bound decision variables: X1 ||| Upper bound: 1000.0
# set upper bound decision variables: Y1 ||| Upper bound: 400.0
# set upper bound decision variables: Z1 ||| Upper bound: 1000.0
# set upper bound decision variables: X2 ||| Upper bound: 1000.0
# set upper bound decision variables: Y2 ||| Upper bound: 500.0
# set upper bound decision variables: Y3 ||| Upper bound: 450.0
# set upper bound decision variables: X3 ||| Upper bound: 1500.0
# set upper bound decision variables: TL1 ||| Upper bound: 20000.0
# set upper bound decision variables: TL2 ||| Upper bound: 20000.0
# set upper bound decision variables: TL3 ||| Upper bound: 20000.0
# create auxiliar variable diff "t" - "t-1":  X1
# create auxiliar variable diff "t" - "t-1":  Y1
# create auxiliar variable diff "t" - "t-1":  Z1
# create auxiliar variable diff "t" - "t-1":  X2
# create auxiliar variable diff "t" - "t-1":  Y2
# create auxiliar variable diff "t" - "t-1":  Y3
# create auxiliar variable diff "t" - "t-1":  X3
# create auxiliar variable diff "t" - "t-1":  TL1
# create auxiliar variable diff "t" - "t-1":  TL2
# create auxiliar variable diff "t" - "t-1":  TL3
# rate change decision var:  X1
# rate change decision var:  Y1
# rate change decision var:  Z1
# rate change decision var:  X2
# rate change decision var:  Y2
# rate change decision var:  Y3
# rate change decision var:  X3
# rate change decision var:  TL1
# rate change decision var:  TL2
# rate change decision var:  TL3
# tank name:  TK_1
# tank name:  TK_2
# tank name:  TK_3
# set fixed value observed values: O1 ||| Fixed value observed: 50.0
# set fixed value observed values: O2 ||| Fixed value observed: 50.0
# set fixed value observed values: O3 ||| Fixed value observed: 50.0
# set fixed value observed values: O4 ||| Fixed value observed: 200.0
# set fixed value observed values: O5 ||| Fixed value observed: 5.0
# set fixed value observed values: O6 ||| Fixed value observed: 5.0
# set fixed value observed values: O7 ||| Fixed value observed: 4.0
#
# name model - model id:  PR_A_Y1
# constraint machine learning model
#
# name model - model id:  PR_B_Y2
# constraint machine learning model
#
# name model - model id:  PR_B_Y3
# constraint machine learning model
#
# name model - model id:  PR_C_Y2
# constraint custom model
# decision var:  X3
# decision var:  O7
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19043.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# WLS license 2441807 - registered to CMPC Celulosa S.A
# Optimize a model with 508 rows, 259 columns and 950 nonzeros
# Model fingerprint: 0xfcbf956d
# Coefficient statistics:
#   Matrix range     [2e-01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+04]
# Presolve removed 336 rows and 169 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible or unbounded model
# There was a problem - infeasible solution
#
#
#
#  index while:  8
#
# name model - model id:  PR_A_Y1
# path model loade:  process_a
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_a/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y2
# path model loade:  process_b_y2
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y2/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y3
# path model loade:  process_b_y3
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y3/model.pkl
# loaded pkl
#
# name model - model id:  PR_C_Y2
# path model loade:  process_c
# artifact model loaded:  model.xlsx
# full path model:  artifacts/models/process_c/model.xlsx
# loaded excel
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2441807
# WLS license 2441807 - registered to CMPC Celulosa S.A
# defining decision variables:  X1
# defining decision variables:  O1
# defining decision variables:  O2
# defining decision variables:  O3
# defining decision variables:  Y1
# defining decision variables:  O4
# defining decision variables:  Z1
# defining decision variables:  X2
# ...
# set initial values decision variables: O5 ||| Initial value: 5.0
# set initial values decision variables: O6 ||| Initial value: 5.0
# set initial values decision variables: X3 ||| Initial value: 5.0
# set initial values decision variables: O7 ||| Initial value: 4.0
# set initial values decision variables: TL1 ||| Initial value: 500.0
# set initial values decision variables: TL2 ||| Initial value: 500.0
# set initial values decision variables: TL3 ||| Initial value: 500.0
# set lower bound decision variables: X1 ||| Lower bound: 0.0
# set lower bound decision variables: Y1 ||| Lower bound: 0.0
# set lower bound decision variables: Z1 ||| Lower bound: 0.0
# set lower bound decision variables: X2 ||| Lower bound: 0.0
# set lower bound decision variables: Y2 ||| Lower bound: 0.0
# set lower bound decision variables: Y3 ||| Lower bound: 0.0
# set lower bound decision variables: X3 ||| Lower bound: 0.0
# set lower bound decision variables: TL1 ||| Lower bound: 100.0
# set lower bound decision variables: TL2 ||| Lower bound: 100.0
# set lower bound decision variables: TL3 ||| Lower bound: 100.0
# set upper bound decision variables: X1 ||| Upper bound: 1000.0
# set upper bound decision variables: Y1 ||| Upper bound: 400.0
# set upper bound decision variables: Z1 ||| Upper bound: 1000.0
# set upper bound decision variables: X2 ||| Upper bound: 1000.0
# set upper bound decision variables: Y2 ||| Upper bound: 500.0
# set upper bound decision variables: Y3 ||| Upper bound: 450.0
# set upper bound decision variables: X3 ||| Upper bound: 1500.0
# set upper bound decision variables: TL1 ||| Upper bound: 20000.0
# set upper bound decision variables: TL2 ||| Upper bound: 20000.0
# set upper bound decision variables: TL3 ||| Upper bound: 20000.0
# create auxiliar variable diff "t" - "t-1":  X1
# create auxiliar variable diff "t" - "t-1":  Y1
# create auxiliar variable diff "t" - "t-1":  Z1
# create auxiliar variable diff "t" - "t-1":  X2
# create auxiliar variable diff "t" - "t-1":  Y2
# create auxiliar variable diff "t" - "t-1":  Y3
# create auxiliar variable diff "t" - "t-1":  X3
# create auxiliar variable diff "t" - "t-1":  TL1
# create auxiliar variable diff "t" - "t-1":  TL2
# create auxiliar variable diff "t" - "t-1":  TL3
# rate change decision var:  X1
# rate change decision var:  Y1
# rate change decision var:  Z1
# rate change decision var:  X2
# rate change decision var:  Y2
# rate change decision var:  Y3
# rate change decision var:  X3
# rate change decision var:  TL1
# rate change decision var:  TL2
# rate change decision var:  TL3
# tank name:  TK_1
# tank name:  TK_2
# tank name:  TK_3
# set fixed value observed values: O1 ||| Fixed value observed: 50.0
# set fixed value observed values: O2 ||| Fixed value observed: 50.0
# set fixed value observed values: O3 ||| Fixed value observed: 50.0
# set fixed value observed values: O4 ||| Fixed value observed: 200.0
# set fixed value observed values: O5 ||| Fixed value observed: 5.0
# set fixed value observed values: O6 ||| Fixed value observed: 5.0
# set fixed value observed values: O7 ||| Fixed value observed: 4.0
#
# name model - model id:  PR_A_Y1
# constraint machine learning model
#
# name model - model id:  PR_B_Y2
# constraint machine learning model
#
# name model - model id:  PR_B_Y3
# constraint machine learning model
#
# name model - model id:  PR_C_Y2
# constraint custom model
# decision var:  X3
# decision var:  O7
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19043.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# WLS license 2441807 - registered to CMPC Celulosa S.A
# Optimize a model with 508 rows, 259 columns and 950 nonzeros
# Model fingerprint: 0x3ea271f3
# Coefficient statistics:
#   Matrix range     [2e-01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+04]
# Presolve removed 346 rows and 169 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible or unbounded model
# There was a problem - infeasible solution
#
#
#
#  index while:  30
#
# name model - model id:  PR_A_Y1
# path model loade:  process_a
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_a/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y2
# path model loade:  process_b_y2
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y2/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y3
# path model loade:  process_b_y3
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y3/model.pkl
# loaded pkl
#
# name model - model id:  PR_C_Y2
# path model loade:  process_c
# artifact model loaded:  model.xlsx
# full path model:  artifacts/models/process_c/model.xlsx
# loaded excel
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2441807
# WLS license 2441807 - registered to CMPC Celulosa S.A
# defining decision variables:  X1
# defining decision variables:  O1
# defining decision variables:  O2
# defining decision variables:  O3
# defining decision variables:  Y1
# defining decision variables:  O4
# defining decision variables:  Z1
# defining decision variables:  X2
# defining decision variables:  O5
# defining decision variables:  O6
# defining decision variables:  Y2
# defining decision variables:  Y3
# defining decision variables:  X3
# defining decision variables:  O7
# defining decision variables:  TL1
# defining decision variables:  TL2
# defining decision variables:  TL3
# set initial values decision variables: X1 ||| Initial value: 50.0
# set initial values decision variables: O1 ||| Initial value: 50.0
# set initial values decision variables: O2 ||| Initial value: 50.0
# set initial values decision variables: O3 ||| Initial value: 50.0
# set initial values decision variables: O4 ||| Initial value: 200.0
# set initial values decision variables: X2 ||| Initial value: 5.0
# set initial values decision variables: O5 ||| Initial value: 5.0
# set initial values decision variables: O6 ||| Initial value: 5.0
# set initial values decision variables: X3 ||| Initial value: 5.0
# set initial values decision variables: O7 ||| Initial value: 4.0
# set initial values decision variables: TL1 ||| Initial value: 500.0
# set initial values decision variables: TL2 ||| Initial value: 500.0
# set initial values decision variables: TL3 ||| Initial value: 500.0
# set lower bound decision variables: X1 ||| Lower bound: 0.0
# set lower bound decision variables: Y1 ||| Lower bound: 0.0
# set lower bound decision variables: Z1 ||| Lower bound: 0.0
# Warning: environment still referenced so free is deferred (Continue to use WLS)
# set lower bound decision variables: X2 ||| Lower bound: 0.0
# set lower bound decision variables: Y2 ||| Lower bound: 0.0
# set lower bound decision variables: Y3 ||| Lower bound: 0.0
# set lower bound decision variables: X3 ||| Lower bound: 0.0
# set lower bound decision variables: TL1 ||| Lower bound: 100.0
# set lower bound decision variables: TL2 ||| Lower bound: 100.0
# set lower bound decision variables: TL3 ||| Lower bound: 100.0
# set upper bound decision variables: X1 ||| Upper bound: 1000.0
# set upper bound decision variables: Y1 ||| Upper bound: 400.0
# set upper bound decision variables: Z1 ||| Upper bound: 1000.0
# set upper bound decision variables: X2 ||| Upper bound: 1000.0
# set upper bound decision variables: Y2 ||| Upper bound: 500.0
# set upper bound decision variables: Y3 ||| Upper bound: 450.0
# set upper bound decision variables: X3 ||| Upper bound: 1500.0
# set upper bound decision variables: TL1 ||| Upper bound: 20000.0
# set upper bound decision variables: TL2 ||| Upper bound: 20000.0
# set upper bound decision variables: TL3 ||| Upper bound: 20000.0
# create auxiliar variable diff "t" - "t-1":  X1
# create auxiliar variable diff "t" - "t-1":  Y1
# create auxiliar variable diff "t" - "t-1":  Z1
# create auxiliar variable diff "t" - "t-1":  X2
# create auxiliar variable diff "t" - "t-1":  Y2
# create auxiliar variable diff "t" - "t-1":  Y3
# create auxiliar variable diff "t" - "t-1":  X3
# create auxiliar variable diff "t" - "t-1":  TL1
# create auxiliar variable diff "t" - "t-1":  TL2
# create auxiliar variable diff "t" - "t-1":  TL3
# rate change decision var:  X1
# rate change decision var:  Y1
# rate change decision var:  Z1
# rate change decision var:  X2
# rate change decision var:  Y2
# rate change decision var:  Y3
# rate change decision var:  X3
# rate change decision var:  TL1
# rate change decision var:  TL2
# rate change decision var:  TL3
# tank name:  TK_1
# tank name:  TK_2
# tank name:  TK_3
# set fixed value observed values: O1 ||| Fixed value observed: 50.0
# set fixed value observed values: O2 ||| Fixed value observed: 50.0
# set fixed value observed values: O3 ||| Fixed value observed: 50.0
# set fixed value observed values: O4 ||| Fixed value observed: 200.0
# set fixed value observed values: O5 ||| Fixed value observed: 5.0
# set fixed value observed values: O6 ||| Fixed value observed: 5.0
# set fixed value observed values: O7 ||| Fixed value observed: 4.0
#
# name model - model id:  PR_A_Y1
# constraint machine learning model
#
# name model - model id:  PR_B_Y2
# constraint machine learning model
#
# name model - model id:  PR_B_Y3
# constraint machine learning model
#
# name model - model id:  PR_C_Y2
# constraint custom model
# decision var:  X3
# decision var:  O7
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19043.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# WLS license 2441807 - registered to CMPC Celulosa S.A
# Optimize a model with 508 rows, 259 columns and 950 nonzeros
# Model fingerprint: 0x7392b50a
# Coefficient statistics:
#   Matrix range     [2e-01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+04]
# Presolve removed 346 rows and 169 columns
# Presolve time: 0.01s
#
# Solved in 0 iterations and 0.01 seconds (0.00 work units)
# Infeasible or unbounded model
# There was a problem - infeasible solution
#
#
#
#  index while:  31
#
# name model - model id:  PR_A_Y1
# path model loade:  process_a
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_a/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y2
# path model loade:  process_b_y2
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y2/model.pkl
# loaded pkl
#
# name model - model id:  PR_B_Y3
# path model loade:  process_b_y3
# artifact model loaded:  model.pkl
# full path model:  artifacts/models/process_b_y3/model.pkl
# loaded pkl
#
# name model - model id:  PR_C_Y2
# path model loade:  process_c
# artifact model loaded:  model.xlsx
# full path model:  artifacts/models/process_c/model.xlsx
# loaded excel
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2441807
# WLS license 2441807 - registered to CMPC Celulosa S.A
# defining decision variables:  X1
# defining decision variables:  O1
# defining decision variables:  O2
# defining decision variables:  O3
# defining decision variables:  Y1
# defining decision variables:  O4
# defining decision variables:  Z1
# defining decision variables:  X2
# defining decision variables:  O5
# defining decision variables:  O6
# defining decision variables:  Y2
# defining decision variables:  Y3
# defining decision variables:  X3
# defining decision variables:  O7
# defining decision variables:  TL1
# defining decision variables:  TL2
# defining decision variables:  TL3
# set initial values decision variables: X1 ||| Initial value: 50.0
# set initial values decision variables: O1 ||| Initial value: 50.0
# set initial values decision variables: O2 ||| Initial value: 50.0
# set initial values decision variables: O3 ||| Initial value: 50.0
# set initial values decision variables: O4 ||| Initial value: 200.0
# set initial values decision variables: X2 ||| Initial value: 5.0
# set initial values decision variables: O5 ||| Initial value: 5.0
# set initial values decision variables: O6 ||| Initial value: 5.0
# set initial values decision variables: X3 ||| Initial value: 5.0
# set initial values decision variables: O7 ||| Initial value: 4.0
# set initial values decision variables: TL1 ||| Initial value: 500.0
# set initial values decision variables: TL2 ||| Initial value: 500.0
# set initial values decision variables: TL3 ||| Initial value: 500.0
# set lower bound decision variables: X1 ||| Lower bound: 0.0
# set lower bound decision variables: Y1 ||| Lower bound: 0.0
# set lower bound decision variables: Z1 ||| Lower bound: 0.0
# set lower bound decision variables: X2 ||| Lower bound: 0.0
# set lower bound decision variables: Y2 ||| Lower bound: 0.0
# set lower bound decision variables: Y3 ||| Lower bound: 0.0
# set lower bound decision variables: X3 ||| Lower bound: 0.0
# set lower bound decision variables: TL1 ||| Lower bound: 100.0
# set lower bound decision variables: TL2 ||| Lower bound: 100.0
# set lower bound decision variables: TL3 ||| Lower bound: 100.0
# set upper bound decision variables: X1 ||| Upper bound: 1000.0
# set upper bound decision variables: Y1 ||| Upper bound: 400.0
# set upper bound decision variables: Z1 ||| Upper bound: 1000.0
# set upper bound decision variables: X2 ||| Upper bound: 1000.0
# set upper bound decision variables: Y2 ||| Upper bound: 500.0
# set upper bound decision variables: Y3 ||| Upper bound: 450.0
# set upper bound decision variables: X3 ||| Upper bound: 1500.0
# set upper bound decision variables: TL1 ||| Upper bound: 20000.0
# set upper bound decision variables: TL2 ||| Upper bound: 20000.0
# set upper bound decision variables: TL3 ||| Upper bound: 20000.0
# create auxiliar variable diff "t" - "t-1":  X1
# create auxiliar variable diff "t" - "t-1":  Y1
# create auxiliar variable diff "t" - "t-1":  Z1
# create auxiliar variable diff "t" - "t-1":  X2
# create auxiliar variable diff "t" - "t-1":  Y2
# create auxiliar variable diff "t" - "t-1":  Y3
# create auxiliar variable diff "t" - "t-1":  X3
# create auxiliar variable diff "t" - "t-1":  TL1
# create auxiliar variable diff "t" - "t-1":  TL2
# create auxiliar variable diff "t" - "t-1":  TL3
# rate change decision var:  X1
# rate change decision var:  Y1
# rate change decision var:  Z1
# rate change decision var:  X2
# rate change decision var:  Y2
# rate change decision var:  Y3
# rate change decision var:  X3
# rate change decision var:  TL1
# rate change decision var:  TL2
# rate change decision var:  TL3
# tank name:  TK_1
# tank name:  TK_2
# tank name:  TK_3
# set fixed value observed values: O1 ||| Fixed value observed: 50.0
# set fixed value observed values: O2 ||| Fixed value observed: 50.0
# set fixed value observed values: O3 ||| Fixed value observed: 50.0
# set fixed value observed values: O4 ||| Fixed value observed: 200.0
# set fixed value observed values: O5 ||| Fixed value observed: 5.0
# set fixed value observed values: O6 ||| Fixed value observed: 5.0
# set fixed value observed values: O7 ||| Fixed value observed: 4.0
#
# name model - model id:  PR_A_Y1
# constraint machine learning model
#
# name model - model id:  PR_B_Y2
# constraint machine learning model
#
# name model - model id:  PR_B_Y3
# constraint machine learning model
#
# name model - model id:  PR_C_Y2
# constraint custom model
# decision var:  X3
# decision var:  O7
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19043.2))
#
# CPU model: Intel(R) Core(TM) i7-10750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# WLS license 2441807 - registered to CMPC Celulosa S.A
# Optimize a model with 508 rows, 259 columns and 950 nonzeros
# Model fingerprint: 0xbaa9c63b
# Coefficient statistics:
#   Matrix range     [2e-01, 4e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+04]
# Presolve removed 479 rows and 236 columns
# Presolve time: 0.01s
# Presolved: 29 rows, 36 columns, 117 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.8417845e+03   3.908510e+02   0.000000e+00      0s
#       14    2.8676835e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 14 iterations and 0.01 seconds (0.00 work units)
# Optimal objective  2.867683490e+03

# %%
# check status solver
print('status solver: ' , status_solver)
if status_solver != 2:
    print('Infeasible solution')
# Out:
# status solver:  2

# %%
##### REVISAR QUÉ VALORES DE RATE CHANGE QUEDARON DE LAS VARIABLES
mask = config_allvariables['feature_name'].isin(list_tags_to_relax_constraints)
config_allvariables[mask]
# Out:
#     tag feature_name          description clasification_name clasification  \
# 14  TL1          TL1  Tank level - tank 1         Tank level             L
# 15  TL2          TL2  Tank level - tank 2         Tank level             L
# 16  TL3          TL3  Tank level - tank 3         Tank level             L
#
#     lower    upper  rate_change
# 14  100.0  20000.0   191.943425
# 15  100.0  20000.0   191.943425
# 16  100.0  20000.0   191.943425

# %% [markdown]
# ### PRINT SOLUTION

# %%
# get optimal values and save in a dataframe
######## create a dataframe with set as index
solution = pd.DataFrame(index = index_set_time)

######################## save optimal values - features of models (only the features) ########################
solution["var_X1"] = decision_var['X1'].gppd.X
solution["var_O1"] = decision_var['O1'].gppd.X
solution["var_O2"] = decision_var['O2'].gppd.X
solution["var_O3"] = decision_var['O3'].gppd.X
solution["var_Y1"] = decision_var['Y1'].gppd.X
solution["var_O4"] = decision_var['O4'].gppd.X
solution["var_Z1"] = decision_var['Z1'].gppd.X
solution["var_X2"] = decision_var['X2'].gppd.X
solution["var_O5"] = decision_var['O5'].gppd.X
solution["var_O6"] = decision_var['O6'].gppd.X
solution["var_Y2"] = decision_var['Y2'].gppd.X
solution["var_Y3"] = decision_var['Y3'].gppd.X
solution["var_X3"] = decision_var['X3'].gppd.X
solution["var_O7"] = decision_var['O7'].gppd.X
solution["var_TL1"] = decision_var['TL1'].gppd.X
solution["var_TL2"] = decision_var['TL2'].gppd.X
solution["var_TL3"] = decision_var['TL3'].gppd.X

######################## # get value objetive function ########################
opt_objetive_function = model_opt.ObjVal

# %%
# know status optimization
# docu: https://www.gurobi.com/documentation/current/refman/optimization_status_codes.html#sec:StatusCodes
model_opt.Status
# Out:
# 2

# %%
# show value objetive function
opt_objetive_function
# Out:
# 2867.68349007468

# %%
# show value decision variables
solution.T
# Out:
#                  t0          t1          t2           t3           t4  \
# var_X1    50.000000   11.321512   13.188927    15.056341    16.923755
# var_O1    50.000000   50.000000   50.000000    50.000000    50.000000
# var_O2    50.000000   50.000000   50.000000    50.000000    50.000000
# var_O3    50.000000   50.000000   50.000000    50.000000    50.000000
# var_Y1   107.250509   89.193871   90.065653    90.937436    91.809218
# var_O4   200.000000  200.000000  200.000000   200.000000   200.000000
# var_Z1   107.016235   97.250446   98.122228    98.994011    99.865793
# var_X2     5.000000   25.574675   43.010320    60.445966    77.881611
# var_O5     5.000000    5.000000    5.000000     5.000000     5.000000
# var_O6     5.000000    5.000000    5.000000     5.000000     5.000000
# var_Y2    61.000000   81.000000  101.000000   121.000000   141.000000
# var_Y3   213.532470  191.943425  191.943425   191.943425   191.943425
# var_X3     5.000000  105.000000  205.000000   305.000000   405.000000
# var_O7     4.000000    4.000000    4.000000     4.000000     4.000000
# var_TL1  500.000000  691.943425  883.886850  1075.830275  1267.773700
# var_TL2  500.000000  581.000000  682.000000   803.000000   944.000000
# var_TL3  500.000000  691.943425  883.886850  1075.830275  1267.773700
#
#                   t5           t6
# var_X1     18.791169    20.658583
# var_O1     50.000000    50.000000
# var_O2     50.000000    50.000000
# var_O3     50.000000    50.000000
# var_Y1     92.681000    93.552783
# var_O4    200.000000   200.000000
# var_Z1    100.737575   101.609358
# var_X2     95.317257   112.752902
# var_O5      5.000000     5.000000
# var_O6      5.000000     5.000000
# var_Y2    161.000000   181.000000
# var_Y3    191.943425   191.943425
# var_X3    505.000000   605.000000
# var_O7      4.000000     4.000000
# var_TL1  1459.717125  1651.660550
# var_TL2  1105.000000  1286.000000
# var_TL3  1459.717125  1651.660550

# %% [markdown]
# ## IMPORTANTE MI SOLUCIÓN ACTUAL ES RELAJADO LOS RATE CHANGE DE LAS VARIABLES DE DECISIÓN Y CON LOS VALORES DE LOS RATE CHANGE DE TANQUES TAMBIÉN RELAJADOS
